# %% [markdown]
# ## Observations and Insights
# Three observations:
#     * The number of mice per drug ranged from aobut 150 to 230, and the ratio of males to females was very close to 50/50.
#     * My average tumor volume data for the 4 best drug treatements did not have any outliers.
#     * Mice treated with Capomulin and Ramicane finished the trial with smaller tumor sizes compared to those on Ceftamin and Infubinol.
#     * Mouse weights had a strong positive correlation to tumor size.  The larger the mouse, the larger the tumor.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import scipy.stats as st
import numpy as np 

# Study data files
mouse_metadata_path = "data/Mouse_metadata.csv"
study_results_path = "data/Study_results.csv"

# Read the mouse data and the study results
mouse_metadata = pd.read_csv(mouse_metadata_path)
study_results = pd.read_csv(study_results_path)

# %%
mouse_metadata
# Out:
#     Mouse ID Drug Regimen     Sex  Age_months  Weight (g)
# 0       k403     Ramicane    Male          21          16
# 1       s185    Capomulin  Female           3          17
# 2       x401    Capomulin  Female          16          15
# 3       m601    Capomulin    Male          22          17
# 4       g791     Ramicane    Male          11          16
# ..       ...          ...     ...         ...         ...
# 244     z314     Stelasyn  Female          21          28
# 245     z435     Propriva  Female          12          26
# 246     z581    Infubinol  Female          24          25
# 247     z795     Naftisol  Female          13          29
# 248     z969     Naftisol    Male           9          30
#
# [249 rows x 5 columns]

# %%
mouse_metadata["Mouse ID"].value_counts()
# Out:
# a897    1
# v719    1
# g107    1
# q582    1
# n304    1
#        ..
# e213    1
# j119    1
# i386    1
# s508    1
# b759    1
# Name: Mouse ID, Length: 249, dtype: int64

# %%
study_results["Mouse ID"].value_counts()
# Out:
# g989    13
# c757    10
# t565    10
# i177    10
# q787    10
#         ..
# x226     1
# v199     1
# f932     1
# o848     1
# b447     1
# Name: Mouse ID, Length: 249, dtype: int64

# %%
# Combine the data into a single dataset
combined_data = pd.merge(mouse_metadata, study_results)
# Display the data table for preview
combined_data
# Out:
#      Mouse ID Drug Regimen   Sex  Age_months  Weight (g)  Timepoint  \
# 0        k403     Ramicane  Male          21          16          0
# 1        k403     Ramicane  Male          21          16          5
# 2        k403     Ramicane  Male          21          16         10
# 3        k403     Ramicane  Male          21          16         15
# 4        k403     Ramicane  Male          21          16         20
# ...       ...          ...   ...         ...         ...        ...
# 1888     z969     Naftisol  Male           9          30         25
# 1889     z969     Naftisol  Male           9          30         30
# 1890     z969     Naftisol  Male           9          30         35
# 1891     z969     Naftisol  Male           9          30         40
# 1892     z969     Naftisol  Male           9          30         45
#
#       Tumor Volume (mm3)  Metastatic Sites
# 0              45.000000                 0
# 1              38.825898                 0
# ...

# %%
# Checking the number of mice.
combined_data["Mouse ID"].value_counts()
# Out:
# g989    13
# c757    10
# c832    10
# c402    10
# m650    10
#         ..
# u153     1
# f932     1
# x226     1
# t573     1
# b447     1
# Name: Mouse ID, Length: 249, dtype: int64

# %%
# Getting the duplicate mice by ID number that shows up for Mouse ID and Timepoint. 
combined_data.loc[combined_data["Mouse ID"] == "g989", :]
# Out:
#     Mouse ID Drug Regimen     Sex  Age_months  Weight (g)  Timepoint  \
# 908     g989     Propriva  Female          21          26          0
# 909     g989     Propriva  Female          21          26          0
# 910     g989     Propriva  Female          21          26          5
# 911     g989     Propriva  Female          21          26          5
# 912     g989     Propriva  Female          21          26         10
# 913     g989     Propriva  Female          21          26         10
# 914     g989     Propriva  Female          21          26         15
# 915     g989     Propriva  Female          21          26         15
# 916     g989     Propriva  Female          21          26         20
# 917     g989     Propriva  Female          21          26         20
# 918     g989     Propriva  Female          21          26         25
# 919     g989     Propriva  Female          21          26         30
# 920     g989     Propriva  Female          21          26         35
#
# ...

# %%
combined_data.loc[combined_data["Mouse ID"] == "x581", :]
# Out:
#      Mouse ID Drug Regimen     Sex  Age_months  Weight (g)  Timepoint  \
# 1764     x581     Ceftamin  Female          19          28          0
# 1765     x581     Ceftamin  Female          19          28          5
# 1766     x581     Ceftamin  Female          19          28         10
# 1767     x581     Ceftamin  Female          19          28         15
# 1768     x581     Ceftamin  Female          19          28         20
# 1769     x581     Ceftamin  Female          19          28         25
# 1770     x581     Ceftamin  Female          19          28         30
# 1771     x581     Ceftamin  Female          19          28         35
# 1772     x581     Ceftamin  Female          19          28         40
# 1773     x581     Ceftamin  Female          19          28         45
#
#       Tumor Volume (mm3)  Metastatic Sites
# 1764           45.000000                 0
# 1765           47.196927                 0
# 1766           49.067028                 1
# ...

# %%
# Optional: Get all the data for the duplicate mouse ID.

# %%
# Create a clean DataFrame by dropping the duplicate mouse by its ID.
cleancombineddata = combined_data.loc[combined_data["Mouse ID"] != "g989", :]
cleancombineddata
# Out:
#      Mouse ID Drug Regimen   Sex  Age_months  Weight (g)  Timepoint  \
# 0        k403     Ramicane  Male          21          16          0
# 1        k403     Ramicane  Male          21          16          5
# 2        k403     Ramicane  Male          21          16         10
# 3        k403     Ramicane  Male          21          16         15
# 4        k403     Ramicane  Male          21          16         20
# ...       ...          ...   ...         ...         ...        ...
# 1888     z969     Naftisol  Male           9          30         25
# 1889     z969     Naftisol  Male           9          30         30
# 1890     z969     Naftisol  Male           9          30         35
# 1891     z969     Naftisol  Male           9          30         40
# 1892     z969     Naftisol  Male           9          30         45
#
#       Tumor Volume (mm3)  Metastatic Sites
# 0              45.000000                 0
# 1              38.825898                 0
# ...

# %%
# Checking the number of mice in the clean DataFrame.
cleancombineddata["Mouse ID"].value_counts()
# Out:
# c757    10
# a262    10
# a685    10
# c402    10
# m650    10
#         ..
# b447     1
# f932     1
# x226     1
# t573     1
# u153     1
# Name: Mouse ID, Length: 248, dtype: int64

# %% [markdown]
# ## Summary Statistics

# %%
# Generate a summary statistics table of mean, median, variance, standard deviation, and SEM of the tumor volume for each regimen

# This method is the most straighforward, creating multiple series and putting them all together at the end.

mean = cleancombineddata.groupby("Drug Regimen")["Tumor Volume (mm3)"].mean()
median = cleancombineddata.groupby("Drug Regimen")["Tumor Volume (mm3)"].median()
variance = cleancombineddata.groupby("Drug Regimen")["Tumor Volume (mm3)"].var()
stdev = cleancombineddata.groupby("Drug Regimen")["Tumor Volume (mm3)"].std()
sem = cleancombineddata.groupby("Drug Regimen")["Tumor Volume (mm3)"].sem()
summarystats = pd.DataFrame({"Mean": mean, "Median": median, "Variance": variance, "Standard Deviation": stdev, 
                          "SEM": sem})
summarystats
# Out:
#                    Mean     Median   Variance  Standard Deviation       SEM
# Drug Regimen
# Capomulin     40.675741  41.557809  24.947764            4.994774  0.329346
# Ceftamin      52.591172  51.776157  39.290177            6.268188  0.469821
# Infubinol     52.884795  51.820584  43.128684            6.567243  0.492236
# Ketapril      55.235638  53.698743  68.553577            8.279709  0.603860
# Naftisol      54.331565  52.509285  66.173479            8.134708  0.596466
# Placebo       54.033581  52.288934  61.168083            7.821003  0.581331
# Propriva      52.320930  50.446266  43.852013            6.622085  0.544332
# Ramicane      40.216745  40.673236  23.486704            4.846308  0.320955
# Stelasyn      54.233149  52.431737  59.450562            7.710419  0.573111
# Zoniferol     53.236507  51.818479  48.533355            6.966589  0.516398

# %%
# Generate a summary statistics table of mean, median, variance, standard deviation, and SEM of the tumor volume for each regimen

# This method produces everything in a single groupby function
summarydata2 = cleancombineddata.groupby('Drug Regimen')["Tumor Volume (mm3)"].describe()
summarydata2
# Out:
#               count       mean       std        min        25%        50%  \
# Drug Regimen
# Capomulin     230.0  40.675741  4.994774  23.343598  37.685933  41.557809
# Ceftamin      178.0  52.591172  6.268188  45.000000  47.208427  51.776157
# Infubinol     178.0  52.884795  6.567243  36.321346  47.312353  51.820584
# Ketapril      188.0  55.235638  8.279709  45.000000  48.232987  53.698743
# Naftisol      186.0  54.331565  8.134708  45.000000  47.285874  52.509285
# Placebo       181.0  54.033581  7.821003  45.000000  47.459053  52.288934
# Propriva      148.0  52.320930  6.622085  45.000000  46.894328  50.446266
# Ramicane      228.0  40.216745  4.846308  22.050126  36.674635  40.673236
# Stelasyn      181.0  54.233149  7.710419  45.000000  48.047139  52.431737
# Zoniferol     182.0  53.236507  6.966589  45.000000  47.337876  51.818479
#
#                     75%        max
# Drug Regimen
# Capomulin     45.000000  48.158209
# Ceftamin      56.801438  68.923185
# ...

# %% [markdown]
# ## Bar and Pie Charts

# %%
# Generate a bar plot showing the total number of mice for each treatment throughout the course of the study using pandas. 
DrugRegimendf = pd.DataFrame(cleancombineddata.groupby(['Drug Regimen']).count()).reset_index()
Regimendatapts = DrugRegimendf[["Drug Regimen","Mouse ID"]]
Regimendatapts = Regimendatapts.set_index("Drug Regimen")
Regimendatapts.plot(kind="bar")

plt.title("Number of Mice per Drug Regimen")
# Out:
# Text(0.5, 1.0, 'Number of Mice per Drug Regimen')

# %%
# Generate a bar plot showing the total number of mice for each treatment throughout the course of the study using pyplot.
Regimens = Regimendatapts.index.tolist()
Regimens
# Out:
# ['Capomulin',
#  'Ceftamin',
#  'Infubinol',
#  'Ketapril',
#  'Naftisol',
#  'Placebo',
#  'Propriva',
#  'Ramicane',
#  'Stelasyn',
#  'Zoniferol']

# %%
MouseCounts = Regimendatapts["Mouse ID"].tolist()
MouseCounts
# Out:
# [230, 178, 178, 188, 186, 181, 148, 228, 181, 182]

# %%
plt.bar(Regimens, MouseCounts, color='b')
plt.xticks(rotation=90)
plt.xlabel("Drug Regimen")
plt.title("Number of Mice per Drug Regimen")
plt.legend("Mouse ID", loc="upper center")
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
# Generate a pie plot showing the distribution of female versus male mice using pandas
Gendercount = pd.DataFrame(cleancombineddata.groupby(['Sex']).count()).reset_index()
Gendercount
# Out:
#       Sex  Mouse ID  Drug Regimen  Age_months  Weight (g)  Timepoint  \
# 0  Female       922           922         922         922        922
# 1    Male       958           958         958         958        958
#
#    Tumor Volume (mm3)  Metastatic Sites
# 0                 922               922
# 1                 958               958

# %%
Gender_df=pd.DataFrame({"Genders": ["Male", "Female"],
                      "Gender_Count": [958, 922]})
Gender_df
# Out:
#   Genders  Gender_Count
# 0    Male           958
# 1  Female           922

# %%
Gender_df.plot(kind='pie',y='Gender_Count', autopct='%1.1f%%', labels = Gender_df["Genders"], legend=False)

# %%
# Generate a pie plot showing the distribution of female versus male mice using pyplot

Genders = ["Male", "Female"]
Gender_Count = [958, 922]
plt.pie(Gender_Count, labels=Genders, autopct="%1.1f%%")
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %% [markdown]
# ## Quartiles, Outliers and Boxplots

# %%
# Calculate the final tumor volume of each mouse across four of the treatment regimens:  
# Capomulin, Ramicane, Infubinol, and Ceftamin

# Start by getting the last (greatest) timepoint for each mouse


# Merge this group df with the original dataframe to get the tumor volume at the last timepoint

# %%
# Start by getting the last (greatest) timepoint for each mouse
sorted_data = cleancombineddata.sort_values("Timepoint", ascending=False)
sorted_data
# Out:
#      Mouse ID Drug Regimen     Sex  Age_months  Weight (g)  Timepoint  \
# 1892     z969     Naftisol    Male           9          30         45
# 1344     p136    Zoniferol  Female           5          28         45
# 874      g296    Zoniferol  Female          14          29         45
# 884      g497     Ketapril    Male          19          28         45
# 360      g316    Capomulin  Female          22          22         45
# ...       ...          ...     ...         ...         ...        ...
# 1170     m269     Stelasyn  Female          22          28          0
# 1164     m133     Naftisol  Female           2          26          0
# 1163     l872      Placebo    Male          19          30          0
# 1153     l733     Ceftamin  Female           4          30          0
# 953      i635     Propriva    Male          21          26          0
#
#       Tumor Volume (mm3)  Metastatic Sites
# 1892           73.867845                 4
# ...

# %%
# Start by getting the last (greatest) timepoint for each mouse
maxvolumes = sorted_data.loc[sorted_data["Timepoint"]==45]
maxvolumes.reset_index()
# Out:
#      index Mouse ID Drug Regimen     Sex  Age_months  Weight (g)  Timepoint  \
# 0     1892     z969     Naftisol    Male           9          30         45
# 1     1344     p136    Zoniferol  Female           5          28         45
# 2      874     g296    Zoniferol  Female          14          29         45
# 3      884     g497     Ketapril    Male          19          28         45
# 4      360     g316    Capomulin  Female          22          22         45
# ..     ...      ...          ...     ...         ...         ...        ...
# 125    440     i557    Capomulin  Female           1          24         45
# 126   1703     w422     Ketapril  Female          18          26         45
# 127    587     a963     Stelasyn  Female          23          27         45
# 128   1518     s337    Zoniferol    Male          14          27         45
# 129    550     a699     Propriva  Female           5          28         45
#
#      Tumor Volume (mm3)  Metastatic Sites
# ...

# %%
maxvolstats = maxvolumes.groupby("Drug Regimen")["Tumor Volume (mm3)"].describe()
maxvolstats
#maxvolstats = maxvolumes.['Tumor Volume (mm3)'].describe()
#maxvolstats
# Out:
#               count       mean       std        min        25%        50%  \
# Drug Regimen
# Capomulin      21.0  36.236114  5.608969  23.343598  32.377357  37.311846
# Ceftamin       13.0  64.132421  3.253497  59.741901  61.433892  64.299830
# Infubinol       9.0  65.755562  3.433282  60.918767  62.754451  66.083066
# Ketapril       11.0  70.662958  4.819674  62.909441  67.129166  69.872251
# Naftisol       13.0  69.265506  5.106770  62.670759  63.946640  69.563621
# Placebo        11.0  68.084082  4.483167  58.634971  65.955820  69.042841
# Propriva        7.0  66.258529  4.996728  58.633404  63.551389  64.957562
# Ramicane       20.0  34.955595  5.486439  22.050126  30.981175  34.848627
# Stelasyn       11.0  68.438310  5.228845  60.122011  64.053452  69.299149
# Zoniferol      14.0  65.960888  3.755037  60.752704  62.618149  65.684689
#
#                     75%        max
# Drug Regimen
# Capomulin     40.159220  47.685963
# Ceftamin      67.527482  68.923185
# ...

# %%
maxvolstats = maxvolstats.drop("Ketapril", axis = 0)
maxvolstats = maxvolstats.drop("Naftisol", axis = 0)
maxvolstats = maxvolstats.drop("Placebo", axis = 0)
maxvolstats = maxvolstats.drop("Propriva", axis = 0)
maxvolstats = maxvolstats.drop("Stelasyn", axis = 0)
maxvolstats = maxvolstats.drop("Zoniferol", axis = 0)

maxvolstats
# Out:
#               count       mean       std        min        25%        50%  \
# Drug Regimen
# Capomulin      21.0  36.236114  5.608969  23.343598  32.377357  37.311846
# Ceftamin       13.0  64.132421  3.253497  59.741901  61.433892  64.299830
# Infubinol       9.0  65.755562  3.433282  60.918767  62.754451  66.083066
# Ramicane       20.0  34.955595  5.486439  22.050126  30.981175  34.848627
#
#                     75%        max
# Drug Regimen
# Capomulin     40.159220  47.685963
# Ceftamin      67.527482  68.923185
# Infubinol     67.685569  72.226731
# Ramicane      38.508305  45.220869

# %%
# Put treatments into a list for for loop (and later for plot labels)
# Capomulin, Ramicane, Infubinol, and Ceftamin
Treatment_list = ["Capomulin", "Ramicane", "Infubinol", "Ceftamin"]

# Create empty list to fill with tumor vol data (for plotting)
Tumor_vol_data = []

# Calculate the IQR and quantitatively determine if there are any potential outliers. 
IQR_Cap = 40.159220 - 32.377357
lowerbound_Cap = 23.343598 - (1.5*IQR_Cap)
upperbound_Cap = 40.159220 + (1.5*IQR_Cap)
print(f"Any value below {lowerbound_Cap} or above {upperbound_Cap} could be outliers for Capumulin.")
    
IQR_Ceft = 67.527482 - 61.433892
lowerbound_Ceft = 61.433892 - (1.5*IQR_Ceft)
upperbound_Ceft = 67.527482 + (1.5*IQR_Ceft)
print(f"Any value below {lowerbound_Ceft} or above {upperbound_Ceft} could be outliers for Ceftamin.")

IQR_Inf = 67.685569 - 62.754451
lowerbound_Inf = 62.754451 - (1.5*IQR_Inf)
upperbound_Inf = 67.685569 + (1.5*IQR_Inf)
print(f"Any value below {lowerbound_Inf} or above {upperbound_Inf} could be outliers for Infubinol.")

IQR_Rem = 38.508305 - 30.981175
lowerbound_Rem = 30.981175 - (1.5*IQR_Rem)
upperbound_Rem = 38.508305 + (1.5*IQR_Rem)
print(f"Any value below {lowerbound_Rem} or above {upperbound_Rem} could be outliers for Remicane.")


    
    
    
    # add subset 
    
    
    # Determine outliers using upper and lower bounds
# Out:
# Any value below 11.670803500000009 or above 51.832014499999985 could be outliers for Capumulin.
# Any value below 52.29350699999999 or above 76.66786700000002 could be outliers for Ceftamin.
# Any value below 55.357774000000006 or above 75.082246 could be outliers for Infubinol.
# Any value below 19.69048 or above 49.799 could be outliers for Remicane.

# %%
# Locate the rows which contain mice on each drug and get the tumor volumes
Capomulin = maxvolumes.loc[maxvolumes["Drug Regimen"]=="Capomulin"] 
Ramicane = maxvolumes.loc[maxvolumes["Drug Regimen"]=="Ramicane"] 
Infubinol = maxvolumes.loc[maxvolumes["Drug Regimen"]=="Infubinol"] 
Ceftamin = maxvolumes.loc[maxvolumes["Drug Regimen"]=="Ceftamin"]

# %%
# Generate a box plot of the final tumor volume of each mouse across four regimens of interest
cap_vol_data = Capomulin["Tumor Volume (mm3)"].tolist()
ram_vol_data = Ramicane["Tumor Volume (mm3)"].tolist()
inf_vol_data = Infubinol["Tumor Volume (mm3)"].tolist()
ceft_vol_data = Ceftamin["Tumor Volume (mm3)"].tolist()

box_plot_data = [cap_vol_data, ram_vol_data, inf_vol_data, ceft_vol_data]
plt.boxplot(box_plot_data, labels=['Capumulin', "Ramicane", "Infubinol", "Ceftamin"])
plt.title("Final Tumor Volumes for Best Treatments")
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %% [markdown]
# ## Line and Scatter Plots

# %%
# Generate a line plot of time point versus tumor volume for a mouse treated with Capomulin
Capomulin
# Out:
#     Mouse ID Drug Regimen     Sex  Age_months  Weight (g)  Timepoint  \
# 360     g316    Capomulin  Female          22          22         45
# 124     y793    Capomulin    Male          17          17         45
# 350     v923    Capomulin  Female          19          21         45
# 134     r554    Capomulin  Female           8          17         45
# 337     j119    Capomulin  Female           7          23         45
# 144     m957    Capomulin  Female           3          19         45
# 370     s710    Capomulin  Female           1          23         45
# 390     r944    Capomulin    Male          12          25         45
# 104     u364    Capomulin    Male          18          17         45
# 380     l509    Capomulin    Male          17          21         45
# 244     g288    Capomulin    Male           3          19         45
# 204     i738    Capomulin  Female          23          20         45
# 224     w914    Capomulin    Male          24          21         45
# ...

# %%
mice_treatedby_capomulin = Capomulin["Mouse ID"].tolist()
mice_treatedby_capomulin
# Out:
# ['g316',
#  'y793',
#  'v923',
#  'r554',
#  'j119',
#  'm957',
#  's710',
#  'r944',
#  'u364',
#  'l509',
#  'g288',
#  'i738',
#  'w914',
#  't565',
#  'b128',
#  'b742',
#  'l897',
#  's185',
#  'm601',
#  'x401',
#  'i557']

# %%
g316_cap = combined_data.loc[combined_data["Mouse ID"]== "g316"]
g316_cap
# Out:
#     Mouse ID Drug Regimen     Sex  Age_months  Weight (g)  Timepoint  \
# 351     g316    Capomulin  Female          22          22          0
# 352     g316    Capomulin  Female          22          22          5
# 353     g316    Capomulin  Female          22          22         10
# 354     g316    Capomulin  Female          22          22         15
# 355     g316    Capomulin  Female          22          22         20
# 356     g316    Capomulin  Female          22          22         25
# 357     g316    Capomulin  Female          22          22         30
# 358     g316    Capomulin  Female          22          22         35
# 359     g316    Capomulin  Female          22          22         40
# 360     g316    Capomulin  Female          22          22         45
#
#      Tumor Volume (mm3)  Metastatic Sites
# 351           45.000000                 0
# 352           44.022752                 0
# 353           44.502042                 0
# ...

# %%
g316_times = g316_cap["Timepoint"].tolist()
g316_volumes = g316_cap["Tumor Volume (mm3)"].tolist()
g316_times
g316_volumes
plt.plot(g316_times, g316_volumes)
plt.title("Tumor Volume Over Time for Mouse g316")
plt.xlabel("Timepoint")
plt.ylabel("Tumor Volume (mm3)")
#plt.show
# Out:
# Text(0, 0.5, 'Tumor Volume (mm3)')

# %%
# Generate a scatter plot of mouse weight versus average tumor volume for the Capomulin regimen
average_tumor_vol_cap = pd.DataFrame(Capomulin.groupby(["Mouse ID","Weight (g)"])["Tumor Volume (mm3)"].mean()).reset_index()
average_tumor_vol_cap = average_tumor_vol_cap.rename(columns={"Tumor Volume (mm3)": "Average Tumor Volume (mm3)"})
average_tumor_vol_cap = average_tumor_vol_cap.set_index("Mouse ID")
average_tumor_vol_cap
# Out:
#           Weight (g)  Average Tumor Volume (mm3)
# Mouse ID
# b128              22                   38.982878
# b742              21                   38.939633
# g288              19                   37.074024
# g316              22                   40.159220
# i557              24                   47.685963
# i738              20                   37.311846
# j119              23                   38.125164
# l509              21                   41.483008
# l897              19                   38.846876
# m601              17                   28.430964
# m957              19                   33.329098
# r554              17                   32.377357
# r944              25                   41.581521
# s185              17                   23.343598
# s710              23                   40.728578
# t565              17                   34.455298
# u364              17                   31.023923
# v923              21                   40.658124
# ...

# %%
average_tumor_vol_cap.plot(kind="scatter", x="Weight (g)", y="Average Tumor Volume (mm3)", title="Mouse Weight vs. Average Tumor Volume")

# %% [markdown]
# ## Correlation and Regression

# %%
# Calculate the correlation coefficient and linear regression model 
# for mouse weight and average tumor volume for the Capomulin regimen
mouse_weights_cap = average_tumor_vol_cap["Weight (g)"].tolist()
mouse_avgTvol_cap = average_tumor_vol_cap["Average Tumor Volume (mm3)"].tolist()
r=st.pearsonr(mouse_weights_cap,mouse_avgTvol_cap)
print(f"The correlation between mouse weight and average tumor volume for Capomulin is {r[0]}")
# Out:
# The correlation between mouse weight and average tumor volume for Capomulin is 0.8490719078173735

# %%
x_val = average_tumor_vol_cap["Weight (g)"]
y_val = average_tumor_vol_cap["Average Tumor Volume (mm3)"]
plt.scatter(x_val, y_val)

slope, intercept, r_value, p_value, std_err = st.linregress(x_val, y_val)
y = slope * x_val + intercept
plt.plot(x_val, y, color="r")
plt.title("Mouse Weight vs. Average Tumor Volume")
plt.xlabel("Weight (g)")
plt.ylabel("Average Tumor Volume (mm3)")
plt.show()
